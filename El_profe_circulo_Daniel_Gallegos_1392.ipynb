# %% [markdown]
# ### Daniel Gallegos NL = 20 Fecha 25/03/2026
# ---
# # Calcular area y perimetro de un circulo
# ---
# ![Logo de Markdown](https://raw.githubusercontent.com/DanielGallegos128/EPPL-Area-y-perimetro-de-un-circulo-/refs/heads/main/circuloareaperimetro.PNG)
#
# ---
# ## Formula para calcular Area
# $A=π*r^2$
#
# ---
# ## Formula para calcular perimetro
# $P = 2*π*r$
#
# ---
# ## Datos de entrada
# $r$ ?
#
# ---
# ## Diagrama de flujo en LucidChart
# ![Logo de Markdown](https://raw.githubusercontent.com/DanielGallegos128/EPPL-Area-y-perimetro-de-un-circulo-/1eef1d4e2bf4c1ee2fd6150a767287f4844019a6/Diagrama%20en%20blanco.png)

# %%
# Calcular area y perimetro de un circulo
# Variables A, P, r
# Formulas A = pi*r^2
# P = 2 * pi * r
# Capturar el valor de r
import math
print("Calcular area y perimetro de un circulo")
r = float(input("Ingrese el valor de r: "))
A = math.pi*(r**2)
P = 2*math.pi*r
print("El area del circulo es: ", A)
print("El perimetro del circulo es: ", P)
print("Daniel Gallegos NL = 20")
# Out:
# Calcular area y perimetro de un circulo
# Ingrese el valor de r: 5
# El area del circulo es:  78.53981633974483
# El perimetro del circulo es:  31.41592653589793
# Daniel Gallegos NL = 20

# %% [markdown]
# # Relacion entre codigo y diagrama de flujo en Tldraw
# ![](https://raw.githubusercontent.com/DanielGallegos128/EPPL-Area-y-perimetro-de-un-circulo-/refs/heads/main/Sin%20t%C3%ADtulo.png)
